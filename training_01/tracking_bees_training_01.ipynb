# %% [markdown]
# <a href="https://colab.research.google.com/github/chloejeannin/YOLOBee/blob/main/training_01/tracking_bees_training_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Introduction
#
# Second Training starting from the results of the first training but without Validation and detection

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/
# Out:
# /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5

# %%
! git clone https://github.com/martinschatz-cz/SciAugment.git

# %%
# !pip install -r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt -v
# Out:
# Using pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# ...

# %%
from SciAugment.utilities.SciAug_tools import *

# %%
#@markdown Specifie a path to folder with images and YOLO anotations
input_images_folder = '../../01_Data/frames+labels/'  # @param{type: 'string'}
input_image_format = '.jpg'  # @param{type: 'string'}

# %%
aug = SciAugment()
# Out:
# New instance of SciAugment.
# Selected augmentation type: Default
#
#
# Version: 0.1.0
#
#
# Selected augmentation:
# HorizontalFlip(p=1)
# RandomSizedBBoxSafeCrop(250, 250, erosion_rate=0.0, interpolation=1, p=1.0)
# Transpose(1)
# RandomRotate90(p=1)
# ShiftScaleRotate(p=1)
# VerticalFlip(p=1)

# %%
aug.augment_data(images_path=input_images_folder, image_format=input_image_format)
# Out:
# Train_data folder already exists!
# Please remove existing trin_data folder and try again.
# 1

# %%
#import shutil
shutil.make_archive('train_data','zip','/content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/', base_dir='train_data')

# %% [markdown]
# Training
# ---

# %%
#!git clone https://github.com/ultralytics/yolov5  # clone

# %pip install -qr /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/yolov5/requirements.txt  # install

import torch
import sys
sys.path.append('/content/gdrive/Shareddrives/YOLObee_drive/01_Data/YOLOv5/yolov5')
from yolov5 import utils
display = utils.notebook_init()  # checks

# %%
# %cd yolov5/data
# !wget https://github.com/martinschatz-cz/SciCount/raw/main/example_notebooks/WildlifeDetection/class1.yaml
# %cd ..
# Out:
# /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/yolov5/data
# --2024-06-03 08:31:37--  https://github.com/martinschatz-cz/SciCount/raw/main/example_notebooks/WildlifeDetection/class1.yaml
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/martinschatz-cz/SciCount/main/example_notebooks/WildlifeDetection/class1.yaml [following]
# --2024-06-03 08:31:37--  https://raw.githubusercontent.com/martinschatz-cz/SciCount/main/example_notebooks/WildlifeDetection/class1.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 234 [text/plain]
# Saving to: ‘class1.yaml.8’
#
# ...

# %%
# Train YOLOv5s on Smear images augmented train_data for 500 epochs
# !python train.py --img 640 --batch -1 --epochs 300 --data class1.yaml --weights /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/yolov5/runs/train/exp15/weights/best.pt --cache
# Out:
# 2024-06-03 09:04:00.166972: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-03 09:04:00.167031: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-03 09:04:00.168560: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# The training stopped at 100 epochs because there was no improvement.
