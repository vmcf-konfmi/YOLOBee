# %% [markdown]
# <a href="https://colab.research.google.com/github/chloejeannin/YOLOBee/blob/main/training_03/tracking_bees_03_additional_frames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Introduction
#
# The fourth is trained by mixing the frames used in 01 training and 02 training

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/
# Out:
# /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5

# %% [markdown]
# Augmentation
# ---

# %%
#! git clone https://github.com/martinschatz-cz/SciAugment.git

# %%
# !pip install -r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt -v
# Out:
# Using pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Collecting albumentations==1.4.8 (from -r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1))
#   Downloading albumentations-1.4.8-py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python-headless>=3.4.18.65 in /usr/local/lib/python3.10/dist-packages (from -r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 2)) (4.10.0.82)
# Requirement already satisfied: imgaug in /usr/local/lib/python3.10/dist-packages (from -r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (0.4.0)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (1.25.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (1.11.4)
# Collecting scikit-image>=0.21.0 (from albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1))
#   Downloading scikit_image-0.23.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 57.1 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (4.12.1)
# Collecting scikit-learn>=1.3.2 (from albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1))
#   Downloading scikit_learn-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 52.8 MB/s eta 0:00:00
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (2.7.3)
# Collecting albucore>=0.0.4 (from albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1))
#   Downloading albucore-0.0.9-py3-none-any.whl (7.9 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (3.7.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (4.8.0.76)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (2.31.6)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (2.0.4)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from albucore>=0.0.4->albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (2.18.4)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (3.3)
# Collecting imageio (from imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3))
#   Downloading imageio-2.34.1-py3-none-any.whl (313 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.5/313.5 kB 28.9 MB/s eta 0:00:00
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (2024.5.22)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (24.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.2->albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.2->albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (2.8.2)
# Installing collected packages: imageio, scikit-learn, scikit-image, albucore, albumentations
#   Attempting uninstall: imageio
#     Found existing installation: imageio 2.31.6
#     Uninstalling imageio-2.31.6:
#       Removing file or directory /usr/local/bin/imageio_download_bin
#       Removing file or directory /usr/local/bin/imageio_remove_bin
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/imageio-2.31.6.dist-info/
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/imageio/
#       Successfully uninstalled imageio-2.31.6
#   changing mode of /usr/local/bin/imageio_download_bin to 755
#   changing mode of /usr/local/bin/imageio_remove_bin to 755
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/scikit_learn-1.2.2.dist-info/
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/scikit_learn.libs/
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/sklearn/
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.19.3
#     Uninstalling scikit-image-0.19.3:
#       Removing file or directory /usr/local/bin/skivi
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/doc/ext/
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/scikit_image-0.19.3.dist-info/
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/scikit_image.libs/
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/skimage/
#       Successfully uninstalled scikit-image-0.19.3
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 1.3.1
#     Uninstalling albumentations-1.3.1:
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/albumentations-1.3.1.dist-info/
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/albumentations/
#       Successfully uninstalled albumentations-1.3.1
# Successfully installed albucore-0.0.9 albumentations-1.4.8 imageio-2.34.1 scikit-image-0.23.2 scikit-learn-1.5.0

# %%
# !pip install watermark

# %load_ext watermark
# Out:
# Collecting watermark
#   Downloading watermark-2.4.3-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: ipython>=6.0 in /usr/local/lib/python3.10/dist-packages (from watermark) (7.34.0)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.10/dist-packages (from watermark) (7.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from watermark) (67.7.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=1.4->watermark) (3.19.1)
# Collecting jedi>=0.16 (from ipython>=6.0->watermark)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=6.0->watermark) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=6.0->watermark) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.0->watermark) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.0->watermark) (3.0.45)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=6.0->watermark) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=6.0->watermark) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=6.0->watermark) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.0->watermark) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=6.0->watermark) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=6.0->watermark) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.0->watermark) (0.2.13)
# Installing collected packages: jedi, watermark
# Successfully installed jedi-0.19.1 watermark-2.4.3

# %%
# %watermark -v -p albumentations,opencv-python-headless,imgaug,cv2,yolov5,torch
# Out:
# Python implementation: CPython
# Python version       : 3.10.12
# IPython version      : 7.34.0
#
# albumentations        : 1.4.8
# opencv-python-headless: not installed
# imgaug                : 0.4.0
# cv2                   : 4.8.0
# yolov5                : unknown
# torch                 : 2.3.0+cu121

# %%
# @title
# SciAug_tools
import copy
import glob
import math
import os
import random
from shutil import rmtree
from sys import stdout
from xml.dom import minidom

import albumentations as A
import cv2
import imgaug as ia
import imgaug.augmenters as iaa
from imgaug.augmentables.bbs import BoundingBox, BoundingBoxesOnImage


class SciAugment:
    version = "0.2.0"
    source = "https://github.com/martinschatz-cz/SciAugment"
    author = "Martin Schätz"
    aug_type = ""
    augment = []
    channel_augment = []
    aug_dict = {
        -1: "no augmentation",
        0: "HorizontalFlip(p=1)",
        1: "RandomBrightnessContrast(contrast_limit=0.2,p=1)",
        2: "MultiplicativeNoise(multiplier=0.5, p=1)",
        3: "RandomSizedBBoxSafeCrop(250, 250, erosion_rate=0.0, interpolation=1, p=1.0)",
        4: "Blur(blur_limit=(10, 10), p=0)",
        5: "Transpose(1)",
        6: "RandomRotate90(p=1)",
        7: "ShiftScaleRotate(p=1)",
        8: "VerticalFlip(p=1)",
        9: "RandomBrightnessContrast(brightness_limit=0.2,p=1)",
    }

    aug_channel_dict = {
        -1: "no augmentation",
        0: "RandomBrightnessContrast(contrast_limit=0.2,p=1)",
        1: "MultiplicativeNoise(multiplier=0.5, p=1)",
        2: "Blur(blur_limit=(10, 10), p=0)",
        3: "RandomBrightnessContrast(brightness_limit=0.2,p=1)",
        4: "Superpixels (p_replace=0.1, n_segments=20, max_size=64, interpolation=1, p=1)",
        5: "GaussNoise (var_limit=(10.0, 50.0), mean=0, p=1)",
    }

    #######general functions###########
    def __new__(cls, *args, **kwargs):
        print("New instance of SciAugment.")
        return super().__new__(cls)

    def __init__(self, aug_type: str = "Default", channel_aug: bool = False):
        self.augmet_type = aug_type
        print("Selected augmentation type: {}".format(self.augmet_type))
        if aug_type == "Default":
            self.augment = [-1, 0, 3, 5, 6, 7, 8]
            if channel_aug:
                self.channel_augment = range(-1, 5, 1)

        if aug_type == "fluorescece_microscopy":
            self.augment = range(-1, 9, 1)
            if channel_aug:
                self.channel_augment = [-1, 1, 2, 3, 4, 5]

        if aug_type == "all":
            self.augment = range(-1, 9, 1)
            if channel_aug:
                self.channel_augment = range(-1, 5, 1)

        if aug_type == "no_augment":
            self.augment = [-1]
            print(
                "No augment setting will only divide images and labels to train_data folder."
            )
            self.channel_augment = []

        print("\n")
        self.explain()

    def explain(self):
        print("Version: {}".format(self.version))
        print("\n")
        print("Selected augmentation:")
        for aug in self.augment:
            print(self.aug_dict[aug])

        if self.channel_augment:
            print("\n")
            print("Selected channel wise augmentation:")
            for ch_aug in self.channel_augment:
                print(self.aug_channel_dict[ch_aug])

    def info(self):
        print("Version: {}".format(self.version))
        print("\n")
        print("Selected augmentation:")
        for aug in self.augment:
            print(self.aug_dict[aug])

        if self.channel_augment:
            print("\n")
            print("Selected channel wise augmentation:")
            for ch_aug in self.channel_augment:
                print(self.aug_channel_dict[ch_aug])

        print("\n")
        print("\n")
        print("Source: {}".format(self.source))
        print("Author: {}".format(self.author))

    def read_image(self, images_path: str, filename: str):
        """
        Uses OpenCV to read RGB images
        :param images_path (str):
        :param filename (str):
        :return: RGB image
        """

        # OpenCV uses BGR channels
        img = cv2.imread(images_path + filename)
        return img

    def read_image_unchanged(self, images_path: str, filename: str):
        """
        Uses OpenCV to read RGBA or 4 channel (maximum) images
        :param images_path (str):
        :param filename (str):
        :return: RGB image
        """
        # https://learnopencv.com/read-an-image-in-opencv-python-cpp/
        # OpenCV uses BGR channels
        img = cv2.imread(
            images_path + filename, cv2.IMREAD_UNCHANGED | cv2.IMREAD_ANYDEPTH
        )
        return img

    def read_yolo(self, filename: str) -> float:
        """
        Reads YOLO type of object anotation for albumentation to read
        :param filename (str):
        :return yolo_coords:
        """
        yolo_coords = []
        with open(filename, "r") as fname:
            for yolo in fname:
                x = yolo.strip().split(" ")
                x.append(x[0])
                x.pop(0)
                x[0] = float(x[0])
                x[1] = float(x[1])
                x[2] = float(x[2])
                x[3] = float(x[3])
                # print(x)
                yolo_coords.append(x)
        return yolo_coords

    def write_yolo(self, coords: float, name: str):
        """
        Write YOLO type object coordinates to txt file
        :param coords (float): list of coordinates
        :param name (str): name of file to write to
        :return:
        """
        with open(name + ".txt", "w") as f:
            for x in coords:
                f.write("%s %s %s %s %s \n" % (x[-1], x[0], x[1], x[2], x[3]))
        return 0

    def create_train_data_folder(self):
        try:
            dir = "train_data"
            if os.path.exists(dir):
                print("Train_data folder already exists!")  # , and will be removed.')
                return 1
                # shutil.rmtree(dir)
            else:
                os.mkdir(dir)

            # info_path = dir + '/info.txt'
            # with open(info_path, 'w') as f:
            #   f.writelines(self.info())

            dir_image_train = "train_data/images/train"
            dir_image_val = "train_data/images/val"
            dir_label_train = "train_data/labels/train"
            dir_label_val = "train_data/labels/val"

            os.mkdir("train_data/images")
            os.mkdir("train_data/labels")
            os.mkdir(dir_image_train)
            os.mkdir(dir_image_val)
            os.mkdir(dir_label_train)
            os.mkdir(dir_label_val)

            return 0
        except:
            print("Error while creating new train_data folder structure!")
            return 1

    #########transform functions########
    def get_transform(loop: int):
        """
      # !!!OLD FUNCTION, DO NOT USE!!!
              Generating image an label augmentation for YOLO with name tag of augmentations.

              :param loop (int): Number of augmentation from 0 to 8

              :return:
              A: transform function with BboxParams set for Yolo
              name (string): Name where relevant to position is bit length 11 for:
                1:Shift
                2:Scale
                3:Rotate
                4:VerticalFlip
                5:HorizontalFlip
                6:RandomContrast
                7:MultiplicativeNoise(multiplier=0.5, p=1)
                8:RandomSizedBBoxSafeCrop (250, 250, erosion_rate=0.0, interpolation=1, p=1.0)
                9:Blur(blur_limit=(10, 10), p=0)
                10:Transpose
                11:RandomRotate90
                12:RandomBrightness
        """
        if loop == 0:
            transform = A.Compose(
                [
                    A.HorizontalFlip(p=1),
                ],
                bbox_params=A.BboxParams(format="yolo"),
            )
            name = "00001000000"
        elif loop == 1:
            transform = A.Compose(
                [
                    A.RandomBrightnessContrast(p=1),
                ],
                bbox_params=A.BboxParams(format="yolo"),
            )
            name = "00000100000"
        elif loop == 2:
            transform = A.Compose(
                [
                    A.HorizontalFlip(p=0),
                    A.MultiplicativeNoise(multiplier=0.5, p=1),
                ],
                bbox_params=A.BboxParams(format="yolo"),
            )
            name = "00000010000"
        elif loop == 3:
            transform = A.Compose(
                [
                    # A.CenterCrop(width=250, height=250, p=1)
                    A.RandomSizedBBoxSafeCrop(
                        250, 250, erosion_rate=0.0, interpolation=1, p=1.0
                    )
                ],
                bbox_params=A.BboxParams(format="yolo"),
            )
            name = "00000001000"
        elif loop == 4:
            transform = A.Compose(
                [A.Blur(blur_limit=(10, 10), p=1)],
                bbox_params=A.BboxParams(format="yolo"),
            )
            name = "00000000100"
        elif loop == 5:
            transform = A.Compose(
                [A.Transpose(p=11)], bbox_params=A.BboxParams(format="yolo")
            )
            name = "00000000010"
        elif loop == 6:
            transform = A.Compose(
                [A.RandomRotate90(p=1)], bbox_params=A.BboxParams(format="yolo")
            )
            name = "00000000001"
        elif loop == 7:
            transform = A.Compose(
                [A.ShiftScaleRotate(p=1)], bbox_params=A.BboxParams(format="yolo")
            )
            name = "11100000000"
        elif loop == 8:
            transform = A.Compose(
                [A.VerticalFlip(p=1)], bbox_params=A.BboxParams(format="yolo")
            )
            name = "00010000000"
        # elif loop == 7:
        #     transform = A.Compose([
        #         A.ImageCompression(quality_lower=0, quality_upper=1, p=0.2)
        #     ], bbox_params=A.BboxParams(format='yolo'))
        # elif loop == 8:
        #     transform = A.Compose([
        #         A.CoarseDropout(max_holes=50, max_height=40,
        #                  max_width=40, fill_value=128, p=0)
        #     ], bbox_params=A.BboxParams(format='pascal_voc'))

        # transform = A.Compose([
        #         A.HorizontalFlip(p=1),
        #     ], bbox_params=A.BboxParams(format='yolo'))

        return transform, name

    def _h_flip():
        transform = A.Compose(
            [
                A.HorizontalFlip(p=1),
            ],
            bbox_params=A.BboxParams(format="yolo"),
        )
        name = "000010000000"
        return transform, name

    def _rand_contrast():
        transform = A.Compose(
            [
                A.RandomBrightnessContrast(contrast_limit=0.2, p=1),
            ],
            bbox_params=A.BboxParams(format="yolo"),
        )
        name = "000001000000"
        return transform, name

    def _multi_noise():
        transform = A.Compose(
            [
                A.HorizontalFlip(p=0),
                A.MultiplicativeNoise(multiplier=0.5, p=1),
            ],
            bbox_params=A.BboxParams(format="yolo"),
        )
        name = "000000100000"
        return transform, name

    def _rand_size_crop():
        transform = A.Compose(
            [
                # A.CenterCrop(width=250, height=250, p=1)
                A.RandomSizedBBoxSafeCrop(
                    250, 250, erosion_rate=0.0, interpolation=1, p=1.0
                )
            ],
            bbox_params=A.BboxParams(format="yolo"),
        )
        name = "000000010000"
        return transform, name

    def _im_blur():
        transform = A.Compose(
            [A.Blur(blur_limit=(10, 10), p=1)], bbox_params=A.BboxParams(format="yolo")
        )
        name = "000000001000"
        return transform, name

    def _im_transpose():
        transform = A.Compose(
            [A.Transpose(p=1)], bbox_params=A.BboxParams(format="yolo")
        )
        name = "000000000100"
        return transform, name

    def _rand_rotate():
        transform = A.Compose(
            [A.RandomRotate90(p=1)], bbox_params=A.BboxParams(format="yolo")
        )
        name = "000000000010"
        return transform, name

    def _shift_scale_rotate():
        transform = A.Compose(
            [A.ShiftScaleRotate(p=1)], bbox_params=A.BboxParams(format="yolo")
        )
        name = "111000000000"
        return transform, name

    def _v_flip():
        transform = A.Compose(
            [A.VerticalFlip(p=1)], bbox_params=A.BboxParams(format="yolo")
        )
        name = "000100000000"
        return transform, name

    def _no_augment():
        transform = A.Compose(
            [A.VerticalFlip(p=0)], bbox_params=A.BboxParams(format="yolo")
        )
        name = "000000000000"
        return transform, name

    def _rand_brightness():
        transform = A.Compose(
            [
                A.RandomBrightnessContrast(brightness_limit=0.2, p=1),
            ],
            bbox_params=A.BboxParams(format="yolo"),
        )
        name = "000000000001"
        return transform, name

    # for 16 bit A.ToFloat(max_value=65535.0),
    #     """
    #       1:Shift
    #       2:Scale
    #       3:Rotate
    #       4:VerticalFlip
    #       5:HorizontalFlip
    #       6:RandomBrightnessContrast
    #       7:MultiplicativeNoise(multiplier=0.5, p=1)
    #       8:RandomSizedBBoxSafeCrop (250, 250, erosion_rate=0.0, interpolation=1, p=1.0)
    #       9:Blur(blur_limit=(10, 10), p=0)
    #       10:Transpose
    #       11:RandomRotate90
    #     """

    aug_functions = {
        -1: _no_augment,
        0: _h_flip,
        1: _rand_contrast,
        2: _multi_noise,
        3: _rand_size_crop,
        4: _im_blur,
        5: _im_transpose,
        6: _rand_rotate,
        7: _shift_scale_rotate,
        8: _v_flip,
        9: _rand_brightness,
    }

    # add functions
    def _no_augment_ch():
        transform = A.Compose([A.VerticalFlip(p=0)])
        name = "-NA"
        return transform, name

    def _rand_contrast_ch():
        transform = A.Compose([A.RandomBrightnessContrast(contrast_limit=0.2, p=1)])
        name = "-RC"
        return transform, name

    def _multi_noise_ch():
        transform = A.Compose([A.MultiplicativeNoise(multiplier=0.5, p=1)])
        name = "-MN"
        return transform, name

    def _im_blur_ch():
        transform = A.Compose([A.Blur(blur_limit=(10, 10), p=1)])
        name = "-B"
        return transform, name

    def _rand_brightness_ch():
        transform = A.Compose([A.RandomBrightnessContrast(brightness_limit=0.2, p=1)])
        name = "-RB"
        return transform, name

    def _superpixels_ch():
        transform = A.Compose(
            [
                A.Superpixels(
                    p_replace=0.1, n_segments=20, max_size=64, interpolation=1, p=1
                )
            ]
        )
        name = "-SP"
        return transform, name

    def _gauss_noise_ch():
        transform = A.Compose([A.GaussNoise(var_limit=(10.0, 50.0), mean=0, p=1)])
        name = "-GN"
        return transform, name

    channel_aug_functions = {
        -1: _no_augment_ch,
        0: _rand_contrast_ch,
        1: _multi_noise_ch,
        2: _im_blur_ch,
        3: _rand_brightness_ch,
        4: _superpixels_ch,
        5: _gauss_noise_ch,
    }

    #####apply functions######
    def augment_data(
        self,
        images_path: str,
        train: float = 0.7,
        image_format: str = ".png",
        output_image_format: str = ".jpg",
    ):
        """
        Augment input images and YOLO files as defined in get_transform() function and save then in train_dir prepared for training and test/val based on 70/30 rule.
        :param images_path (str):
        :param train (float): train/val parameter for generating training data set, default 70% train 30% val
        :param image_format (str): image format name ('.png' default)
        :return:
        """
        count = 0
        # dir = 'train_data'

        dir_image_train = "train_data/images/train"
        dir_image_val = "train_data/images/val"
        dir_label_train = "train_data/labels/train"
        dir_label_val = "train_data/labels/val"

        folder_err = self.create_train_data_folder()
        if folder_err:
            print("Please remove existing trin_data folder and try again.")
            return 1

        # image_format = ".png"
        # train = 0.7
        test = 1 - train
        files_to_process = sorted(os.listdir(images_path))
        print("Num of files: " + str(len(files_to_process)))

        #define empty title, ext, xmlTitle, txtExt
        title = 'title'
        ext = 'ext'
        xmlTitle = 'xmlTitle'
        txtExt = 'txtExt'

        for filename in files_to_process:
            print("Processing: " + filename)

            if filename.endswith(image_format.lower()) or filename.endswith(
                image_format.upper()
            ):
                title, ext = os.path.splitext(os.path.basename(filename))
                print(images_path)
                print(filename)
                image = self.read_image(images_path, filename)
            if filename.endswith(".txt"):
                xmlTitle, txtExt = os.path.splitext(os.path.basename(filename))
                if xmlTitle == title:
                    # bboxes = getCoordinates(filename)
                    bboxes = self.read_yolo(images_path + xmlTitle + ".txt")
                    print(images_path + xmlTitle + ".txt")
                    for aug in self.augment:
                        img = copy.deepcopy(image)
                        transform, name_tag = self.aug_functions[aug]()
                        dice = random.uniform(0, 1)
                        # try:
                        transformed = transform(image=img, bboxes=bboxes)
                        transformed_image = transformed["image"]
                        transformed_bboxes = transformed["bboxes"]
                        name = (
                            title
                            + "_"
                            + str(count)
                            + "_"
                            + name_tag
                            + output_image_format
                        )
                        # print(name)
                        if dice <= train:
                            p_name = dir_image_train + "/" + name
                        else:
                            p_name = dir_image_val + "/" + name

                        cv2.imwrite(p_name, transformed_image)
                        print("Writing " + name)
                        # print(transformed_bboxes)
                        # writeVoc(transformed_bboxes, count, transformed_image)
                        # pTitle='/content/'+dir+'/'+title
                        if dice <= train:
                            p_title = (
                                dir_label_train
                                + "/"
                                + title
                                + "_"
                                + str(count)
                                + "_"
                                + name_tag
                            )
                        else:
                            p_title = (
                                dir_label_val
                                + "/"
                                + title
                                + "_"
                                + str(count)
                                + "_"
                                + name_tag
                            )

                        self.write_yolo(transformed_bboxes, p_title)
                        count = count + 1
                        # except:
                        # print("Bounding Box exception!!!")
                        # pass
        print("Process created {} images".format(count))

    def augment_data_per_channel(
        self,
        images_path: str,
        train: float = 0.7,
        image_format: str = ".png",
        output_image_format: str = ".png",
    ):
        """
        Augment input images and YOLO files as defined in get_transform() function and save then in train_dir prepared for training and test/val based on 70/30 rule.
        :param images_path (str):
        :param train (float): train/val parameter for generating training data set, default 70% train 30% val
        :param image_format (str): image format name ('.png' default)
        :return:
        """
        count = 0
        # dir = 'train_data'

        dir_image_train = "train_data/images/train"
        dir_image_val = "train_data/images/val"
        dir_label_train = "train_data/labels/train"
        dir_label_val = "train_data/labels/val"

        folder_err = self.create_train_data_folder()
        if folder_err:
            print("Please remove existing trin_data folder and try again.")
            return 1

        # image_format = ".png"
        # train = 0.7
        test = 1 - train
        files_to_process = sorted(os.listdir(images_path))
        print("Num of files: " + str(len(files_to_process)))

        for filename in files_to_process:
            print("Processing: " + filename)

            if filename.endswith(image_format.lower()) or filename.endswith(
                image_format.upper()
            ):
                title, ext = os.path.splitext(os.path.basename(filename))
                print(images_path)
                print(filename)
                image = self.read_image_unchanged(images_path, filename)
            if filename.endswith(".txt"):
                xmlTitle, txtExt = os.path.splitext(os.path.basename(filename))
                if xmlTitle == title:
                    # bboxes = getCoordinates(filename)
                    bboxes = self.read_yolo(images_path + xmlTitle + ".txt")
                    print(images_path + xmlTitle + ".txt")
                    for aug in self.augment:
                        img = copy.deepcopy(image)
                        transform, name_tag = self.aug_functions[aug]()
                        dice = random.uniform(0, 1)
                        #####apply also channel augmentation#####
                        # try:
                        transformed = transform(image=img, bboxes=bboxes)
                        transformed_image = transformed["image"]
                        transformed_bboxes = transformed["bboxes"]

                        # go through channel transports
                        for ch_aug in self.channel_augment:

                            transform_ch, ch_name_tag = self.channel_aug_functions[
                                ch_aug
                            ]()

                            # split channels
                            im_split = cv2.split(transformed_image)

                            for ch in range(0, len(im_split), 1):
                                channel = im_split[ch]

                                transformed = transform_ch(image=channel)
                                transformed_channel = transformed["image"]

                                im_merge = copy.deepcopy(im_split)
                                im_merge[ch] = transformed_channel
                                merged_transformed = cv2.merge(im_merge)
                                name_tag_ch = "_ch-" + str(ch + 1) + ch_name_tag
                                # print(name_ch)
                                # cv2_imshow(merged)
                                # save
                                name = (
                                    title
                                    + "_"
                                    + str(count)
                                    + "_"
                                    + name_tag
                                    + name_tag_ch
                                )
                                # print(name)
                                if dice <= train:
                                    p_name = (
                                        dir_image_train
                                        + "/"
                                        + name
                                        + output_image_format
                                    )
                                else:
                                    p_name = (
                                        dir_image_val + "/" + name + output_image_format
                                    )

                                cv2.imwrite(p_name, merged_transformed)
                                print("Writing " + name)
                                # print(transformed_bboxes)
                                # writeVoc(transformed_bboxes, count, transformed_image)
                                # pTitle='/content/'+dir+'/'+title
                                if dice <= train:
                                    p_title = dir_label_train + "/" + name
                                else:
                                    p_title = dir_label_val + "/" + name

                                self.write_yolo(transformed_bboxes, p_title)
                                count = count + 1
                        # except:
                        # print("Augmentation exception!!!")
                        # pass
        print("Process created {} images".format(count))

# %%
from SciAugment.utilities.SciAug_tools import *

# %%
#@markdown Specifie a path to folder with images and YOLO anotations
input_images_folder = '/content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/'  # @param{type: 'string'}
input_image_format = '.jpg'  # @param{type: 'string'}

# %%
aug = SciAugment()
# Out:
# New instance of SciAugment.
# Selected augmentation type: Default
#
#
# Version: 0.1.0
#
#
# Selected augmentation:
# HorizontalFlip(p=1)
# RandomSizedBBoxSafeCrop(250, 250, erosion_rate=0.0, interpolation=1, p=1.0)
# Transpose(1)
# RandomRotate90(p=1)
# ShiftScaleRotate(p=1)
# VerticalFlip(p=1)

# %%
aug.augment_data(images_path=input_images_folder, image_format=input_image_format)
# Out:
# Num of files: 157
# Processing: Copie de frame_0001.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0001.jpg
# Processing: Copie de frame_0001.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0001.txt
# Writing Copie de frame_0001_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0001_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0001_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0001_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0001_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0001_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0002.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0002.jpg
# Processing: Copie de frame_0002.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0002.txt
# Writing Copie de frame_0002_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0002_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0002_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0002_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0002_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0002_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0003.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0003.jpg
# Processing: Copie de frame_0003.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0003.txt
# Writing Copie de frame_0003_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0003_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0003_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0003_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0003_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0003_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0004.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0004.jpg
# Processing: Copie de frame_0004.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0004.txt
# Writing Copie de frame_0004_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0004_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0004_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0004_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0004_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0004_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0005.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0005.jpg
# Processing: Copie de frame_0005.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0005.txt
# Writing Copie de frame_0005_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0005_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0005_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0005_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0005_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0005_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0006.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0006.jpg
# Processing: Copie de frame_0006.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0006.txt
# Writing Copie de frame_0006_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0006_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0006_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0006_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0006_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0006_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0007.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0007.jpg
# Processing: Copie de frame_0007.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0007.txt
# Writing Copie de frame_0007_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0007_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0007_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0007_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0007_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0007_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0008.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0008.jpg
# Processing: Copie de frame_0008.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0008.txt
# Writing Copie de frame_0008_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0008_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0008_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0008_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0008_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0008_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0009.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0009.jpg
# Processing: Copie de frame_0009.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0009.txt
# Writing Copie de frame_0009_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0009_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0009_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0009_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0009_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0009_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0010.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0010.jpg
# Processing: Copie de frame_0010.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0010.txt
# Writing Copie de frame_0010_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0010_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0010_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0010_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0010_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0010_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0011.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0011.jpg
# Processing: Copie de frame_0011.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0011.txt
# Writing Copie de frame_0011_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0011_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0011_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0011_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0011_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0011_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0012.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0012.jpg
# Processing: Copie de frame_0012.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0012.txt
# Writing Copie de frame_0012_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0012_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0012_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0012_0_00000000001.jpg
# Bounding Box exception!!!
# Bounding Box exception!!!
# Writing Copie de frame_0012_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0013.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0013.jpg
# Processing: Copie de frame_0013.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0013.txt
# Writing Copie de frame_0013_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0013_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0013_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0013_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0013_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0013_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0014.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0014.jpg
# Processing: Copie de frame_0014.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0014.txt
# Writing Copie de frame_0014_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0014_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0014_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0014_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0014_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0014_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0015.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0015.jpg
# Processing: Copie de frame_0015.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0015.txt
# Writing Copie de frame_0015_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0015_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0015_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0015_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0015_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0015_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0015_1.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0015_1.jpg
# Processing: Copie de frame_0015_1.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0015_1.txt
# Writing Copie de frame_0015_1_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0015_1_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0015_1_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0015_1_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0015_1_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0015_1_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0016.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0016.jpg
# Processing: Copie de frame_0016.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0016.txt
# Writing Copie de frame_0016_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0016_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0016_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0016_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0016_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0016_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0016_1.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_
jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0776.jpg
# Processing: Copie de frame_0776.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0776.txt
# Writing Copie de frame_0776_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0776_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0776_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0776_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0776_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0776_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0777.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0777.jpg
# Processing: Copie de frame_0777.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0777.txt
# Writing Copie de frame_0777_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0777_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0777_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0777_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0777_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0777_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0785.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0785.jpg
# Processing: Copie de frame_0785.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0785.txt
# Writing Copie de frame_0785_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0785_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0785_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0785_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0785_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0785_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0787.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0787.jpg
# Processing: Copie de frame_0787.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0787.txt
# Writing Copie de frame_0787_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0787_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0787_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0787_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0787_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0787_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0789.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0789.jpg
# Processing: Copie de frame_0789.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0789.txt
# Writing Copie de frame_0789_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0789_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0789_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0789_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0789_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0789_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0790.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0790.jpg
# Processing: Copie de frame_0790.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0790.txt
# Writing Copie de frame_0790_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0790_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0790_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0790_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0790_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0790_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0794.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0794.jpg
# Processing: Copie de frame_0794.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0794.txt
# Writing Copie de frame_0794_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0794_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0794_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0794_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0794_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0794_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0795.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0795.jpg
# Processing: Copie de frame_0795.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0795.txt
# Writing Copie de frame_0795_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0795_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0795_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0795_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0795_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0795_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0797.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0797.jpg
# Processing: Copie de frame_0797.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0797.txt
# Writing Copie de frame_0797_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0797_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0797_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0797_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0797_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0797_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0798.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0798.jpg
# Processing: Copie de frame_0798.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0798.txt
# Writing Copie de frame_0798_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0798_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0798_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0798_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0798_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0798_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0799.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0799.jpg
# Processing: Copie de frame_0799.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0799.txt
# Writing Copie de frame_0799_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0799_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0799_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0799_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0799_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0799_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0841.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0841.jpg
# Processing: Copie de frame_0841.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0841.txt
# Writing Copie de frame_0841_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0841_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0841_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0841_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0841_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0841_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0844.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0844.jpg
# Processing: Copie de frame_0844.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0844.txt
# Writing Copie de frame_0844_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0844_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0844_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0844_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0844_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0844_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: Copie de frame_0865.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/
# Copie de frame_0865.jpg
# Processing: Copie de frame_0865.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames_04/Copie de frame_0865.txt
# Writing Copie de frame_0865_0_00001000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0865_0_00000001000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0865_0_00000000010.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0865_0_00000000001.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0865_0_11100000000.jpg
# Bounding Box exception!!!
# Writing Copie de frame_0865_0_00010000000.jpg
# Bounding Box exception!!!
# Processing: labels.txt

# %%
import shutil
shutil.make_archive('gdrive/Shareddrives/YOLObee_drive/02_Code/train_data_additional_03','zip','/content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/', base_dir='train_data')

# %%
import shutil
shutil.copytree('/content/train_data','gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/train_data')

# %% [markdown]
# Training
# ---

# %%
# %cd yolov5
# Out:
# /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/yolov5

# %%
#!git clone https://github.com/ultralytics/yolov5  # clone

# %pip install -qr /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/yolov5/requirements.txt  # install


import torch

from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-314-g60dde7f1 Python-3.10.12 torch-2.3.0+cu121 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.0/107.7 GB disk)

# %%
# %cd data
# !wget https://github.com/martinschatz-cz/SciCount/raw/main/example_notebooks/WildlifeDetection/class1.yaml
# %cd ..

# %%
# Train YOLOv5s on Smear images augmented train_data for 800 epochs
# !python train.py --img 640 --batch -1 --epochs 800 --data class1.yaml --weights /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/yolov5/runs/train/best_training_01/weights/best.pt --cache
# Out:
# 2024-06-06 09:49:28.705057: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-06 09:49:28.705107: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-06 09:49:28.707027: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=/content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/yolov5/runs/train/best_training_01/weights/best.pt, cfg=, data=class1.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=800, batch_size=-1, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: ⚠️ YOLOv5 is out of date by 4 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-314-g60dde7f1 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
#
#                  from  n    params  module                                  arguments
#   0                -1  1      5280  models.common.Conv                      [3, 48, 6, 2, 2]
#   1                -1  1     41664  models.common.Conv                      [48, 96, 3, 2]
#   2                -1  2     65280  models.common.C3                        [96, 96, 2]
#   3                -1  1    166272  models.common.Conv                      [96, 192, 3, 2]
#   4                -1  4    444672  models.common.C3                        [192, 192, 4]
#   5                -1  1    664320  models.common.Conv                      [192, 384, 3, 2]
#   6                -1  6   2512896  models.common.C3                        [384, 384, 6]
#   7                -1  1   2655744  models.common.Conv                      [384, 768, 3, 2]
#   8                -1  2   4134912  models.common.C3                        [768, 768, 2]
#   9                -1  1   1476864  models.common.SPPF                      [768, 768, 5]
#  10                -1  1    295680  models.common.Conv                      [768, 384, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  2   1182720  models.common.C3                        [768, 384, 2, False]
#  14                -1  1     74112  models.common.Conv                      [384, 192, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  2    296448  models.common.C3                        [384, 192, 2, False]
#  18                -1  1    332160  models.common.Conv                      [192, 192, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  2   1035264  models.common.C3                        [384, 384, 2, False]
#  21                -1  1   1327872  models.common.Conv                      [384, 384, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  2   4134912  models.common.C3                        [768, 768, 2, False]
#  24      [17, 20, 23]  1     24246  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [192, 384, 768]]
# Model summary: 291 layers, 20871318 parameters, 20871318 gradients, 48.2 GFLOPs
#
# Transferred
640: 100% 8/8 [00:06<00:00,  1.33it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:01<00:00,  1.27it/s]
#                    all        111        316      0.961      0.928      0.962      0.662
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     484/799      13.9G     0.0148   0.005433          0         60        640: 100% 8/8 [00:06<00:00,  1.23it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:01<00:00,  1.23it/s]
#                    all        111        316      0.943       0.94      0.958      0.653
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     485/799      13.9G    0.01493   0.005195          0         58        640: 100% 8/8 [00:05<00:00,  1.33it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:01<00:00,  1.41it/s]
#                    all        111        316      0.959      0.921      0.956      0.655
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     486/799      13.9G    0.01358   0.005119          0         70        640: 100% 8/8 [00:06<00:00,  1.23it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:02<00:00,  1.09s/it]
#                    all        111        316       0.96      0.921      0.955      0.659
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     487/799      13.9G    0.01509   0.005456          0         62        640: 100% 8/8 [00:06<00:00,  1.33it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:01<00:00,  1.36it/s]
#                    all        111        316      0.958      0.921      0.957      0.658
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     488/799      13.9G    0.01674   0.005628          0         72        640: 100% 8/8 [00:06<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:02<00:00,  1.06s/it]
#                    all        111        316      0.961      0.924      0.963      0.654
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     489/799      13.9G    0.01368   0.005171          0         63        640: 100% 8/8 [00:06<00:00,  1.32it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:01<00:00,  1.40it/s]
#                    all        111        316      0.963      0.908      0.962      0.651
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     490/799      13.9G     0.0144   0.005085          0         68        640: 100% 8/8 [00:06<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:01<00:00,  1.05it/s]
#                    all        111        316      0.963      0.915      0.955      0.654
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     491/799      13.9G    0.01436   0.005152          0         81        640: 100% 8/8 [00:06<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:01<00:00,  1.39it/s]
#                    all        111        316      0.961      0.926      0.962      0.658
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     492/799      13.9G    0.01492   0.005135          0         76        640: 100% 8/8 [00:06<00:00,  1.31it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:01<00:00,  1.10it/s]
#                    all        111        316      0.961       0.93      0.964       0.66
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     493/799      13.9G    0.01476    0.00526          0         81        640: 100% 8/8 [00:06<00:00,  1.24it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:01<00:00,  1.31it/s]
#                    all        111        316      0.955      0.936      0.958      0.665
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     494/799      13.9G     0.0151   0.005447          0         74        640: 100% 8/8 [00:06<00:00,  1.33it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:01<00:00,  1.16it/s]
#                    all        111        316      0.951      0.946       0.96      0.663
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     495/799      13.9G    0.01557   0.005166          0         66        640: 100% 8/8 [00:06<00:00,  1.24it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:01<00:00,  1.20it/s]
#                    all        111        316      0.946       0.95      0.961      0.661
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     496/799      13.9G    0.01617   0.005142          0        129        640:  25% 2/8 [00:01<00:04,  1.25it/s]

# %% [markdown]
# The training did not finish because the computer had no longer access to the GPU. The training did not finish because the computer had no longer access to the GPU. So I tried launching again the training but because I had no access to the GPU (only the RAM), it was too long, and I had to stop it.

# %%
# Train YOLOv5s on Smear images augmented train_data for 500 epochs
# !python train.py --img 640 --batch 10 --epochs 300 --data class1.yaml --weights /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/yolov5/runs/train/exp33/weights/best.pt --cache
# Out:
# 2024-06-06 14:14:44.674289: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-06 14:14:44.674362: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-06 14:14:44.810319: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=/content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/yolov5/runs/train/exp33/weights/best.pt, cfg=, data=class1.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=10, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# Command 'git fetch origin' timed out after 5 seconds
# YOLOv5 🚀 v7.0-314-g60dde7f1 Python-3.10.12 torch-2.3.0+cu121 CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
#
#                  from  n    params  module                                  arguments
#   0                -1  1      5280  models.common.Conv                      [3, 48, 6, 2, 2]
#   1                -1  1     41664  models.common.Conv                      [48, 96, 3, 2]
#   2                -1  2     65280  models.common.C3                        [96, 96, 2]
#   3                -1  1    166272  models.common.Conv                      [96, 192, 3, 2]
#   4                -1  4    444672  models.common.C3                        [192, 192, 4]
#   5                -1  1    664320  models.common.Conv                      [192, 384, 3, 2]
#   6                -1  6   2512896  models.common.C3                        [384, 384, 6]
#   7                -1  1   2655744  models.common.Conv                      [384, 768, 3, 2]
#   8                -1  2   4134912  models.common.C3                        [768, 768, 2]
#   9                -1  1   1476864  models.common.SPPF                      [768, 768, 5]
#  10                -1  1    295680  models.common.Conv                      [768, 384, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  2   1182720  models.common.C3                        [768, 384, 2, False]
#  14                -1  1     74112  models.common.Conv                      [384, 192, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  2    296448  models.common.C3                        [384, 192, 2, False]
#  18                -1  1    332160  models.common.Conv                      [192, 192, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  2   1035264  models.common.C3                        [384, 384, 2, False]
#  21                -1  1   1327872  models.common.Conv                      [384, 384, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  2   4134912  models.common.C3                        [768, 768, 2, False]
#  24      [17, 20, 23]  1     24246  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [192, 384, 768]]
# Model summary: 291 layers, 20871318 parameters, 20871318 gradients, 48.2 GFLOPs
#
# Transferred 481/481 items from /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/yolov5/runs/train/exp33/weights/best.pt
# optimizer: SGD(lr=0.01) with parameter groups 79 weight(decay=0.0), 82 weight(decay=0.00046875), 82 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/train_data/labels/train.cache... 239 images, 0 backgrounds, 0 corrupt: 100% 239/239 [00:00<?, ?it/s]
# train: Caching images (0.2GB ram): 100% 239/239 [00:19<00:00, 12.55it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/train_data/labels/val.cache... 111 images, 0 backgrounds, 0 corrupt: 100% 111/111 [00:00<?, ?it/s]
# val: Caching images (0.1GB ram): 100% 111/111 [00:05<00:00, 21.22it/s]
#
# AutoAnchor: 3.92 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp36/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp36
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       0/299         0G    0.01364   0.005114          0         35        640: 100% 24/24 [16:28<00:00, 41.20s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 6/6 [01:38<00:00, 16.49s/it]
#                    all        111        316      0.943      0.949      0.959      0.643
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/299         0G     0.0151   0.005366          0         63        640: 100% 24/24 [16:13<00:00, 40.57s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 6/6 [01:40<00:00, 16.69s/it]
#                    all        111        316      0.957      0.937      0.961      0.645
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/299         0G    0.01726   0.005471          0         47        640: 100% 24/24 [16:14<00:00, 40.61s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 6/6 [01:42<00:00, 17.02s/it]
#                    all        111        316      0.951       0.93      0.947      0.598
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/299         0G    0.02186   0.006407          0         37        640:  54% 13/24 [08:50<07:29, 40.83s/it]

# %% [markdown]
# Validation
# ---

# %%
# !python val.py --weights /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/yolov5/runs/train/exp33/weights/best.pt --img 640 --data class1.yaml
# Out:
# val: data=/content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/yolov5/data/class1.yaml, weights=['/content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/yolov5/runs/train/exp33/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-314-g60dde7f1 Python-3.10.12 torch-2.3.0+cu121 CPU
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# val: Scanning /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/train_data/labels/val.cache... 111 images, 0 backgrounds, 0 corrupt: 100% 111/111 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 