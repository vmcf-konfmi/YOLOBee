# %% [markdown]
# <a href="https://colab.research.google.com/github/chloejeannin/YOLOBee/blob/main/Yolov8/training_s/yolov8_training_06_s.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Introduction:
# Training of the neural network Yolov8s using the dataset created for the training 06. To train the model, 2 GPUs are used.

# %%
# %cd /storage/brno2/home/jeanninc/YOLO/YOLOv8
# Out:
# /auto/brno2/home/jeanninc/YOLO/YOLOv8
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %% [markdown]
# Training
# ---

# %%
# %ls
# Out:
# class1.yaml  runs/        yolov8_training_06_s.ipynb  yolov8s.pt
# data/        train_data/  yolov8n.pt

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.31 🚀 Python-3.10.12 torch-2.3.0a0+6ddf5cf85e.nv24.04 CUDA:0 (NVIDIA A40, 45403MiB)
# Setup complete ✅ (64 CPUs, 503.7 GB RAM, 0.0/0.1 GB disk)

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8s.yaml")  # build a new model from YAML
model = YOLO("yolov8s.pt")  # load a pretrained model (recommended for training)
model = YOLO("yolov8s.yaml").load("yolov8s.pt")  # build from YAML and transfer weights

# Train the model
results = model.train(data="class1.yaml", epochs=800, imgsz=640, batch=-1, cache=True)
# Out:
# Transferred 355/355 items from pretrained weights
# New https://pypi.org/project/ultralytics/8.2.42 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.31 🚀 Python-3.10.12 torch-2.3.0a0+6ddf5cf85e.nv24.04 CUDA:0 (Tesla T4, 14918MiB)
# ...

# %% [markdown]
# end of the 800 epochs

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/storage/brno2/home/jeanninc/YOLO/YOLOv8/runs/detect/training_06_s_part1/weights/last.pt")  # load a partially trained model

# Resume training
results = model.train(resume=True, epochs=1600, device=[0,1])
# Out:
# New https://pypi.org/project/ultralytics/8.2.42 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.31 🚀 Python-3.10.12 torch-2.3.0a0+6ddf5cf85e.nv24.04 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11165MiB)
#                                                                            CUDA:1 (NVIDIA GeForce GTX 1080 Ti, 11165MiB)
# ...

# %% [markdown]
# end of the training

# %%
# Train YOLOv5s on Smear images augmented train_data for 800 epochs
from ultralytics import YOLO

# Load a model
model = YOLO("/storage/brno2/home/jeanninc/YOLO/YOLOv8/runs/detect/training_06_s_part2/weights/last.pt")  # load a partially trained model

# Resume training
results = model.train(epochs=800, device=[0,1])
# Out:
# New https://pypi.org/project/ultralytics/8.2.42 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.31 🚀 Python-3.10.12 torch-2.3.0a0+6ddf5cf85e.nv24.04 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11165MiB)
#                                                                            CUDA:1 (NVIDIA GeForce GTX 1080 Ti, 11165MiB)
# ...

# %% [markdown]
#  it stopped before the end

# %%
# Train YOLOv5s on Smear images augmented train_data for 800 epochs
from ultralytics import YOLO

# Load a model
model = YOLO("/storage/brno2/home/jeanninc/YOLO/YOLOv8/runs/detect/training_06_s_part3/weights/last.pt")  # load a partially trained model

# Resume training
results = model.train(resume=True, device=[0,1])
# Out:
# New https://pypi.org/project/ultralytics/8.2.45 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.31 🚀 Python-3.10.12 torch-2.3.0a0+6ddf5cf85e.nv24.04 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11165MiB)
#                                                                            CUDA:1 (NVIDIA GeForce GTX 1080 Ti, 11165MiB)
# ...

# %%
# Train YOLOv5s on Smear images augmented train_data for 800 epochs
from ultralytics import YOLO

# Load a model
model = YOLO("/storage/brno2/home/jeanninc/YOLO/YOLOv8/runs/detect/training_06_s_part4/weights/last.pt")  # load a partially trained model

# Resume training
results = model.train(epochs=800, device=[0,1])
# Out:
# New https://pypi.org/project/ultralytics/8.2.45 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.31 🚀 Python-3.10.12 torch-2.3.0a0+6ddf5cf85e.nv24.04 CUDA:0 (NVIDIA A40, 45403MiB)
#                                                                            CUDA:1 (NVIDIA A40, 45403MiB)
# ...

# %% [markdown]
# Validation
# ---

# %%
# Evaluate the model's performance on the validation set
model = YOLO("/storage/brno2/home/jeanninc/YOLO/YOLOv8/runs/detect/training_06_s_part4/weights/best.pt")  # load a custom model
results_validation = model.val(imgsz=640,data="class1.yaml")
# Out:
# Ultralytics YOLOv8.2.31 🚀 Python-3.10.12 torch-2.3.0a0+6ddf5cf85e.nv24.04 CUDA:0 (NVIDIA A40, 45403MiB)
# YOLOv8s summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /auto/brno2/home/jeanninc/YOLO/YOLOv8/train_data/labels/val.cache... 304 images, 0 backgrounds, 0 corrupt: 100%|██████████| 304/304 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:04<00:00,  4.31it/s]
# ...

# %% [markdown]
# Detection
# ---

# %% [markdown]
# An extract of the video NORM0001_b.MP4 called **video_2_bees_extract_1.mov**

# %%
#detection
model.predict(source="/storage/brno2/home/jeanninc/video/video_2_bees_extract_1.mov", save=True, imgsz=640, conf=0.5,save_txt=True,save_conf=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/265) /storage/brno2/home/jeanninc/video/video_2_bees_extract_1.mov: 384x640 6 bees, 5.2ms
# video 1/1 (frame 2/265) /storage/brno2/home/jeanninc/video/video_2_bees_extract_1.mov: 384x640 6 bees, 5.0ms
# video 1/1 (frame 3/265) /storage/brno2/home/jeanninc/video/video_2_bees_extract_1.mov: 384x640 5 bees, 5.0ms
# ...

# %% [markdown]
# An extract of the video NORM0001_b.MP4 called **video_2_bees_extract_2.mov**

# %%
model.predict(source="/storage/brno2/home/jeanninc/video/video_2_bees_extract_2.mov", save=True, imgsz=640, conf=0.5,save_txt=True,save_conf=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/215) /storage/brno2/home/jeanninc/video/video_2_bees_extract_2.mov: 384x640 8 bees, 4.9ms
# video 1/1 (frame 2/215) /storage/brno2/home/jeanninc/video/video_2_bees_extract_2.mov: 384x640 9 bees, 5.0ms
# video 1/1 (frame 3/215) /storage/brno2/home/jeanninc/video/video_2_bees_extract_2.mov: 384x640 7 bees, 4.9ms
# ...

# %% [markdown]
# An extract of the video NORM0001_b.MP4 called **video_2_bees_extract_3.mov**

# %%
model.predict(source="/storage/brno2/home/jeanninc/video/video_2_bees_extract_3.mov", save=True, imgsz=640, conf=0.5,save_txt=True,save_conf=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/361) /storage/brno2/home/jeanninc/video/video_2_bees_extract_3.mov: 384x640 6 bees, 5.6ms
# video 1/1 (frame 2/361) /storage/brno2/home/jeanninc/video/video_2_bees_extract_3.mov: 384x640 6 bees, 5.3ms
# video 1/1 (frame 3/361) /storage/brno2/home/jeanninc/video/video_2_bees_extract_3.mov: 384x640 6 bees, 5.1ms
# ...
