# %% [markdown]
# <a href="https://colab.research.google.com/github/chloejeannin/YOLOBee/blob/main/training_02/tracking_bees_02_additional_frames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Introduction
#
# The third training uses the weights calculated with training 01 but uses a dataset composed only of new frames from the initial video.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/
# Out:
# /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5

# %% [markdown]
# Augmentation
# ---

# %%
#! git clone https://github.com/martinschatz-cz/SciAugment.git

# %%
# !pip install -r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt -v
# Out:
# Using pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Collecting albumentations==1.4.8 (from -r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1))
#   Downloading albumentations-1.4.8-py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python-headless>=3.4.18.65 in /usr/local/lib/python3.10/dist-packages (from -r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 2)) (4.9.0.80)
# Requirement already satisfied: imgaug in /usr/local/lib/python3.10/dist-packages (from -r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (0.4.0)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (1.25.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (1.11.4)
# Collecting scikit-image>=0.21.0 (from albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1))
#   Downloading scikit_image-0.23.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 31.6 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (4.12.0)
# Collecting scikit-learn>=1.3.2 (from albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1))
#   Downloading scikit_learn-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 57.2 MB/s eta 0:00:00
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (2.7.2)
# Collecting albucore>=0.0.4 (from albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1))
#   Downloading albucore-0.0.7-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (3.7.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (4.8.0.76)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (2.31.6)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (2.0.4)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from albucore>=0.0.4->albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.3 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.7.0->albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (2.18.3)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (3.3)
# Collecting imageio (from imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3))
#   Downloading imageio-2.34.1-py3-none-any.whl (313 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.5/313.5 kB 23.5 MB/s eta 0:00:00
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (2024.5.22)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (24.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.21.0->albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.2->albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.2->albumentations==1.4.8->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 1)) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (4.52.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug->-r /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/SciAugment/requirements.txt (line 3)) (2.8.2)
# Installing collected packages: imageio, scikit-learn, scikit-image, albucore, albumentations
#   Attempting uninstall: imageio
#     Found existing installation: imageio 2.31.6
#     Uninstalling imageio-2.31.6:
#       Removing file or directory /usr/local/bin/imageio_download_bin
#       Removing file or directory /usr/local/bin/imageio_remove_bin
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/imageio-2.31.6.dist-info/
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/imageio/
#       Successfully uninstalled imageio-2.31.6
#   changing mode of /usr/local/bin/imageio_download_bin to 755
#   changing mode of /usr/local/bin/imageio_remove_bin to 755
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/scikit_learn-1.2.2.dist-info/
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/scikit_learn.libs/
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/sklearn/
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.19.3
#     Uninstalling scikit-image-0.19.3:
#       Removing file or directory /usr/local/bin/skivi
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/doc/ext/
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/scikit_image-0.19.3.dist-info/
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/scikit_image.libs/
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/skimage/
#       Successfully uninstalled scikit-image-0.19.3
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 1.3.1
#     Uninstalling albumentations-1.3.1:
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/albumentations-1.3.1.dist-info/
#       Removing file or directory /usr/local/lib/python3.10/dist-packages/albumentations/
#       Successfully uninstalled albumentations-1.3.1
# Successfully installed albucore-0.0.7 albumentations-1.4.8 imageio-2.34.1 scikit-image-0.23.2 scikit-learn-1.5.0

# %%
# !pip install watermark

# %load_ext watermark
# Out:
# Collecting watermark
#   Downloading watermark-2.4.3-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: ipython>=6.0 in /usr/local/lib/python3.10/dist-packages (from watermark) (7.34.0)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.10/dist-packages (from watermark) (7.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from watermark) (67.7.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=1.4->watermark) (3.19.0)
# Collecting jedi>=0.16 (from ipython>=6.0->watermark)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 17.0 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=6.0->watermark) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=6.0->watermark) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.0->watermark) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.0->watermark) (3.0.45)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=6.0->watermark) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=6.0->watermark) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=6.0->watermark) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.0->watermark) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=6.0->watermark) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=6.0->watermark) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.0->watermark) (0.2.13)
# Installing collected packages: jedi, watermark
# Successfully installed jedi-0.19.1 watermark-2.4.3

# %%
# %watermark -v -p albumentations,opencv-python-headless,imgaug,cv2,yolov5,torch
# Out:
# Python implementation: CPython
# Python version       : 3.10.12
# IPython version      : 7.34.0
#
# albumentations        : 1.4.8
# opencv-python-headless: not installed
# imgaug                : 0.4.0
# cv2                   : 4.8.0
# yolov5                : unknown
# torch                 : 2.3.0+cu121

# %%
# @title
# SciAug_tools
import copy
import glob
import math
import os
import random
from shutil import rmtree
from sys import stdout
from xml.dom import minidom

import albumentations as A
import cv2
import imgaug as ia
import imgaug.augmenters as iaa
from imgaug.augmentables.bbs import BoundingBox, BoundingBoxesOnImage


class SciAugment:
    version = "0.2.0"
    source = "https://github.com/martinschatz-cz/SciAugment"
    author = "Martin Schätz"
    aug_type = ""
    augment = []
    channel_augment = []
    aug_dict = {
        -1: "no augmentation",
        0: "HorizontalFlip(p=1)",
        1: "RandomBrightnessContrast(contrast_limit=0.2,p=1)",
        2: "MultiplicativeNoise(multiplier=0.5, p=1)",
        3: "RandomSizedBBoxSafeCrop(250, 250, erosion_rate=0.0, interpolation=1, p=1.0)",
        4: "Blur(blur_limit=(10, 10), p=0)",
        5: "Transpose(1)",
        6: "RandomRotate90(p=1)",
        7: "ShiftScaleRotate(p=1)",
        8: "VerticalFlip(p=1)",
        9: "RandomBrightnessContrast(brightness_limit=0.2,p=1)",
    }

    aug_channel_dict = {
        -1: "no augmentation",
        0: "RandomBrightnessContrast(contrast_limit=0.2,p=1)",
        1: "MultiplicativeNoise(multiplier=0.5, p=1)",
        2: "Blur(blur_limit=(10, 10), p=0)",
        3: "RandomBrightnessContrast(brightness_limit=0.2,p=1)",
        4: "Superpixels (p_replace=0.1, n_segments=20, max_size=64, interpolation=1, p=1)",
        5: "GaussNoise (var_limit=(10.0, 50.0), mean=0, p=1)",
    }

    #######general functions###########
    def __new__(cls, *args, **kwargs):
        print("New instance of SciAugment.")
        return super().__new__(cls)

    def __init__(self, aug_type: str = "Default", channel_aug: bool = False):
        self.augmet_type = aug_type
        print("Selected augmentation type: {}".format(self.augmet_type))
        if aug_type == "Default":
            self.augment = [-1, 0, 3, 5, 6, 7, 8]
            if channel_aug:
                self.channel_augment = range(-1, 5, 1)

        if aug_type == "fluorescece_microscopy":
            self.augment = range(-1, 9, 1)
            if channel_aug:
                self.channel_augment = [-1, 1, 2, 3, 4, 5]

        if aug_type == "all":
            self.augment = range(-1, 9, 1)
            if channel_aug:
                self.channel_augment = range(-1, 5, 1)

        if aug_type == "no_augment":
            self.augment = [-1]
            print(
                "No augment setting will only divide images and labels to train_data folder."
            )
            self.channel_augment = []

        print("\n")
        self.explain()

    def explain(self):
        print("Version: {}".format(self.version))
        print("\n")
        print("Selected augmentation:")
        for aug in self.augment:
            print(self.aug_dict[aug])

        if self.channel_augment:
            print("\n")
            print("Selected channel wise augmentation:")
            for ch_aug in self.channel_augment:
                print(self.aug_channel_dict[ch_aug])

    def info(self):
        print("Version: {}".format(self.version))
        print("\n")
        print("Selected augmentation:")
        for aug in self.augment:
            print(self.aug_dict[aug])

        if self.channel_augment:
            print("\n")
            print("Selected channel wise augmentation:")
            for ch_aug in self.channel_augment:
                print(self.aug_channel_dict[ch_aug])

        print("\n")
        print("\n")
        print("Source: {}".format(self.source))
        print("Author: {}".format(self.author))

    def read_image(self, images_path: str, filename: str):
        """
        Uses OpenCV to read RGB images
        :param images_path (str):
        :param filename (str):
        :return: RGB image
        """

        # OpenCV uses BGR channels
        img = cv2.imread(images_path + filename)
        return img

    def read_image_unchanged(self, images_path: str, filename: str):
        """
        Uses OpenCV to read RGBA or 4 channel (maximum) images
        :param images_path (str):
        :param filename (str):
        :return: RGB image
        """
        # https://learnopencv.com/read-an-image-in-opencv-python-cpp/
        # OpenCV uses BGR channels
        img = cv2.imread(
            images_path + filename, cv2.IMREAD_UNCHANGED | cv2.IMREAD_ANYDEPTH
        )
        return img

    def read_yolo(self, filename: str) -> float:
        """
        Reads YOLO type of object anotation for albumentation to read
        :param filename (str):
        :return yolo_coords:
        """
        yolo_coords = []
        with open(filename, "r") as fname:
            for yolo in fname:
                x = yolo.strip().split(" ")
                x.append(x[0])
                x.pop(0)
                x[0] = float(x[0])
                x[1] = float(x[1])
                x[2] = float(x[2])
                x[3] = float(x[3])
                # print(x)
                yolo_coords.append(x)
        return yolo_coords

    def write_yolo(self, coords: float, name: str):
        """
        Write YOLO type object coordinates to txt file
        :param coords (float): list of coordinates
        :param name (str): name of file to write to
        :return:
        """
        with open(name + ".txt", "w") as f:
            for x in coords:
                f.write("%s %s %s %s %s \n" % (x[-1], x[0], x[1], x[2], x[3]))
        return 0

    def create_train_data_folder(self):
        try:
            dir = "train_data"
            if os.path.exists(dir):
                print("Train_data folder already exists!")  # , and will be removed.')
                return 1
                # shutil.rmtree(dir)
            else:
                os.mkdir(dir)

            # info_path = dir + '/info.txt'
            # with open(info_path, 'w') as f:
            #   f.writelines(self.info())

            dir_image_train = "train_data/images/train"
            dir_image_val = "train_data/images/val"
            dir_label_train = "train_data/labels/train"
            dir_label_val = "train_data/labels/val"

            os.mkdir("train_data/images")
            os.mkdir("train_data/labels")
            os.mkdir(dir_image_train)
            os.mkdir(dir_image_val)
            os.mkdir(dir_label_train)
            os.mkdir(dir_label_val)

            return 0
        except:
            print("Error while creating new train_data folder structure!")
            return 1

    #########transform functions########
    def get_transform(loop: int):
        """
      # !!!OLD FUNCTION, DO NOT USE!!!
              Generating image an label augmentation for YOLO with name tag of augmentations.

              :param loop (int): Number of augmentation from 0 to 8

              :return:
              A: transform function with BboxParams set for Yolo
              name (string): Name where relevant to position is bit length 11 for:
                1:Shift
                2:Scale
                3:Rotate
                4:VerticalFlip
                5:HorizontalFlip
                6:RandomContrast
                7:MultiplicativeNoise(multiplier=0.5, p=1)
                8:RandomSizedBBoxSafeCrop (250, 250, erosion_rate=0.0, interpolation=1, p=1.0)
                9:Blur(blur_limit=(10, 10), p=0)
                10:Transpose
                11:RandomRotate90
                12:RandomBrightness
        """
        if loop == 0:
            transform = A.Compose(
                [
                    A.HorizontalFlip(p=1),
                ],
                bbox_params=A.BboxParams(format="yolo"),
            )
            name = "00001000000"
        elif loop == 1:
            transform = A.Compose(
                [
                    A.RandomBrightnessContrast(p=1),
                ],
                bbox_params=A.BboxParams(format="yolo"),
            )
            name = "00000100000"
        elif loop == 2:
            transform = A.Compose(
                [
                    A.HorizontalFlip(p=0),
                    A.MultiplicativeNoise(multiplier=0.5, p=1),
                ],
                bbox_params=A.BboxParams(format="yolo"),
            )
            name = "00000010000"
        elif loop == 3:
            transform = A.Compose(
                [
                    # A.CenterCrop(width=250, height=250, p=1)
                    A.RandomSizedBBoxSafeCrop(
                        250, 250, erosion_rate=0.0, interpolation=1, p=1.0
                    )
                ],
                bbox_params=A.BboxParams(format="yolo"),
            )
            name = "00000001000"
        elif loop == 4:
            transform = A.Compose(
                [A.Blur(blur_limit=(10, 10), p=1)],
                bbox_params=A.BboxParams(format="yolo"),
            )
            name = "00000000100"
        elif loop == 5:
            transform = A.Compose(
                [A.Transpose(p=11)], bbox_params=A.BboxParams(format="yolo")
            )
            name = "00000000010"
        elif loop == 6:
            transform = A.Compose(
                [A.RandomRotate90(p=1)], bbox_params=A.BboxParams(format="yolo")
            )
            name = "00000000001"
        elif loop == 7:
            transform = A.Compose(
                [A.ShiftScaleRotate(p=1)], bbox_params=A.BboxParams(format="yolo")
            )
            name = "11100000000"
        elif loop == 8:
            transform = A.Compose(
                [A.VerticalFlip(p=1)], bbox_params=A.BboxParams(format="yolo")
            )
            name = "00010000000"
        # elif loop == 7:
        #     transform = A.Compose([
        #         A.ImageCompression(quality_lower=0, quality_upper=1, p=0.2)
        #     ], bbox_params=A.BboxParams(format='yolo'))
        # elif loop == 8:
        #     transform = A.Compose([
        #         A.CoarseDropout(max_holes=50, max_height=40,
        #                  max_width=40, fill_value=128, p=0)
        #     ], bbox_params=A.BboxParams(format='pascal_voc'))

        # transform = A.Compose([
        #         A.HorizontalFlip(p=1),
        #     ], bbox_params=A.BboxParams(format='yolo'))

        return transform, name

    def _h_flip():
        transform = A.Compose(
            [
                A.HorizontalFlip(p=1),
            ],
            bbox_params=A.BboxParams(format="yolo"),
        )
        name = "000010000000"
        return transform, name

    def _rand_contrast():
        transform = A.Compose(
            [
                A.RandomBrightnessContrast(contrast_limit=0.2, p=1),
            ],
            bbox_params=A.BboxParams(format="yolo"),
        )
        name = "000001000000"
        return transform, name

    def _multi_noise():
        transform = A.Compose(
            [
                A.HorizontalFlip(p=0),
                A.MultiplicativeNoise(multiplier=0.5, p=1),
            ],
            bbox_params=A.BboxParams(format="yolo"),
        )
        name = "000000100000"
        return transform, name

    def _rand_size_crop():
        transform = A.Compose(
            [
                # A.CenterCrop(width=250, height=250, p=1)
                A.RandomSizedBBoxSafeCrop(
                    250, 250, erosion_rate=0.0, interpolation=1, p=1.0
                )
            ],
            bbox_params=A.BboxParams(format="yolo"),
        )
        name = "000000010000"
        return transform, name

    def _im_blur():
        transform = A.Compose(
            [A.Blur(blur_limit=(10, 10), p=1)], bbox_params=A.BboxParams(format="yolo")
        )
        name = "000000001000"
        return transform, name

    def _im_transpose():
        transform = A.Compose(
            [A.Transpose(p=1)], bbox_params=A.BboxParams(format="yolo")
        )
        name = "000000000100"
        return transform, name

    def _rand_rotate():
        transform = A.Compose(
            [A.RandomRotate90(p=1)], bbox_params=A.BboxParams(format="yolo")
        )
        name = "000000000010"
        return transform, name

    def _shift_scale_rotate():
        transform = A.Compose(
            [A.ShiftScaleRotate(p=1)], bbox_params=A.BboxParams(format="yolo")
        )
        name = "111000000000"
        return transform, name

    def _v_flip():
        transform = A.Compose(
            [A.VerticalFlip(p=1)], bbox_params=A.BboxParams(format="yolo")
        )
        name = "000100000000"
        return transform, name

    def _no_augment():
        transform = A.Compose(
            [A.VerticalFlip(p=0)], bbox_params=A.BboxParams(format="yolo")
        )
        name = "000000000000"
        return transform, name

    def _rand_brightness():
        transform = A.Compose(
            [
                A.RandomBrightnessContrast(brightness_limit=0.2, p=1),
            ],
            bbox_params=A.BboxParams(format="yolo"),
        )
        name = "000000000001"
        return transform, name

    # for 16 bit A.ToFloat(max_value=65535.0),
    #     """
    #       1:Shift
    #       2:Scale
    #       3:Rotate
    #       4:VerticalFlip
    #       5:HorizontalFlip
    #       6:RandomBrightnessContrast
    #       7:MultiplicativeNoise(multiplier=0.5, p=1)
    #       8:RandomSizedBBoxSafeCrop (250, 250, erosion_rate=0.0, interpolation=1, p=1.0)
    #       9:Blur(blur_limit=(10, 10), p=0)
    #       10:Transpose
    #       11:RandomRotate90
    #     """

    aug_functions = {
        -1: _no_augment,
        0: _h_flip,
        1: _rand_contrast,
        2: _multi_noise,
        3: _rand_size_crop,
        4: _im_blur,
        5: _im_transpose,
        6: _rand_rotate,
        7: _shift_scale_rotate,
        8: _v_flip,
        9: _rand_brightness,
    }

    # add functions
    def _no_augment_ch():
        transform = A.Compose([A.VerticalFlip(p=0)])
        name = "-NA"
        return transform, name

    def _rand_contrast_ch():
        transform = A.Compose([A.RandomBrightnessContrast(contrast_limit=0.2, p=1)])
        name = "-RC"
        return transform, name

    def _multi_noise_ch():
        transform = A.Compose([A.MultiplicativeNoise(multiplier=0.5, p=1)])
        name = "-MN"
        return transform, name

    def _im_blur_ch():
        transform = A.Compose([A.Blur(blur_limit=(10, 10), p=1)])
        name = "-B"
        return transform, name

    def _rand_brightness_ch():
        transform = A.Compose([A.RandomBrightnessContrast(brightness_limit=0.2, p=1)])
        name = "-RB"
        return transform, name

    def _superpixels_ch():
        transform = A.Compose(
            [
                A.Superpixels(
                    p_replace=0.1, n_segments=20, max_size=64, interpolation=1, p=1
                )
            ]
        )
        name = "-SP"
        return transform, name

    def _gauss_noise_ch():
        transform = A.Compose([A.GaussNoise(var_limit=(10.0, 50.0), mean=0, p=1)])
        name = "-GN"
        return transform, name

    channel_aug_functions = {
        -1: _no_augment_ch,
        0: _rand_contrast_ch,
        1: _multi_noise_ch,
        2: _im_blur_ch,
        3: _rand_brightness_ch,
        4: _superpixels_ch,
        5: _gauss_noise_ch,
    }

    #####apply functions######
    def augment_data(
        self,
        images_path: str,
        train: float = 0.7,
        image_format: str = ".png",
        output_image_format: str = ".jpg",
    ):
        """
        Augment input images and YOLO files as defined in get_transform() function and save then in train_dir prepared for training and test/val based on 70/30 rule.
        :param images_path (str):
        :param train (float): train/val parameter for generating training data set, default 70% train 30% val
        :param image_format (str): image format name ('.png' default)
        :return:
        """
        count = 0
        # dir = 'train_data'

        dir_image_train = "train_data/images/train"
        dir_image_val = "train_data/images/val"
        dir_label_train = "train_data/labels/train"
        dir_label_val = "train_data/labels/val"

        folder_err = self.create_train_data_folder()
        if folder_err:
            print("Please remove existing trin_data folder and try again.")
            return 1

        # image_format = ".png"
        # train = 0.7
        test = 1 - train
        files_to_process = sorted(os.listdir(images_path))
        print("Num of files: " + str(len(files_to_process)))

        #define empty title, ext, xmlTitle, txtExt
        title = 'title'
        ext = 'ext'
        xmlTitle = 'xmlTitle'
        txtExt = 'txtExt'

        for filename in files_to_process:
            print("Processing: " + filename)

            if filename.endswith(image_format.lower()) or filename.endswith(
                image_format.upper()
            ):
                title, ext = os.path.splitext(os.path.basename(filename))
                print(images_path)
                print(filename)
                image = self.read_image(images_path, filename)
            if filename.endswith(".txt"):
                xmlTitle, txtExt = os.path.splitext(os.path.basename(filename))
                if xmlTitle == title:
                    # bboxes = getCoordinates(filename)
                    bboxes = self.read_yolo(images_path + xmlTitle + ".txt")
                    print(images_path + xmlTitle + ".txt")
                    for aug in self.augment:
                        img = copy.deepcopy(image)
                        transform, name_tag = self.aug_functions[aug]()
                        dice = random.uniform(0, 1)
                        # try:
                        transformed = transform(image=img, bboxes=bboxes)
                        transformed_image = transformed["image"]
                        transformed_bboxes = transformed["bboxes"]
                        name = (
                            title
                            + "_"
                            + str(count)
                            + "_"
                            + name_tag
                            + output_image_format
                        )
                        # print(name)
                        if dice <= train:
                            p_name = dir_image_train + "/" + name
                        else:
                            p_name = dir_image_val + "/" + name

                        cv2.imwrite(p_name, transformed_image)
                        print("Writing " + name)
                        # print(transformed_bboxes)
                        # writeVoc(transformed_bboxes, count, transformed_image)
                        # pTitle='/content/'+dir+'/'+title
                        if dice <= train:
                            p_title = (
                                dir_label_train
                                + "/"
                                + title
                                + "_"
                                + str(count)
                                + "_"
                                + name_tag
                            )
                        else:
                            p_title = (
                                dir_label_val
                                + "/"
                                + title
                                + "_"
                                + str(count)
                                + "_"
                                + name_tag
                            )

                        self.write_yolo(transformed_bboxes, p_title)
                        count = count + 1
                        # except:
                        # print("Bounding Box exception!!!")
                        # pass
        print("Process created {} images".format(count))

    def augment_data_per_channel(
        self,
        images_path: str,
        train: float = 0.7,
        image_format: str = ".png",
        output_image_format: str = ".png",
    ):
        """
        Augment input images and YOLO files as defined in get_transform() function and save then in train_dir prepared for training and test/val based on 70/30 rule.
        :param images_path (str):
        :param train (float): train/val parameter for generating training data set, default 70% train 30% val
        :param image_format (str): image format name ('.png' default)
        :return:
        """
        count = 0
        # dir = 'train_data'

        dir_image_train = "train_data/images/train"
        dir_image_val = "train_data/images/val"
        dir_label_train = "train_data/labels/train"
        dir_label_val = "train_data/labels/val"

        folder_err = self.create_train_data_folder()
        if folder_err:
            print("Please remove existing trin_data folder and try again.")
            return 1

        # image_format = ".png"
        # train = 0.7
        test = 1 - train
        files_to_process = sorted(os.listdir(images_path))
        print("Num of files: " + str(len(files_to_process)))

        for filename in files_to_process:
            print("Processing: " + filename)

            if filename.endswith(image_format.lower()) or filename.endswith(
                image_format.upper()
            ):
                title, ext = os.path.splitext(os.path.basename(filename))
                print(images_path)
                print(filename)
                image = self.read_image_unchanged(images_path, filename)
            if filename.endswith(".txt"):
                xmlTitle, txtExt = os.path.splitext(os.path.basename(filename))
                if xmlTitle == title:
                    # bboxes = getCoordinates(filename)
                    bboxes = self.read_yolo(images_path + xmlTitle + ".txt")
                    print(images_path + xmlTitle + ".txt")
                    for aug in self.augment:
                        img = copy.deepcopy(image)
                        transform, name_tag = self.aug_functions[aug]()
                        dice = random.uniform(0, 1)
                        #####apply also channel augmentation#####
                        # try:
                        transformed = transform(image=img, bboxes=bboxes)
                        transformed_image = transformed["image"]
                        transformed_bboxes = transformed["bboxes"]

                        # go through channel transports
                        for ch_aug in self.channel_augment:

                            transform_ch, ch_name_tag = self.channel_aug_functions[
                                ch_aug
                            ]()

                            # split channels
                            im_split = cv2.split(transformed_image)

                            for ch in range(0, len(im_split), 1):
                                channel = im_split[ch]

                                transformed = transform_ch(image=channel)
                                transformed_channel = transformed["image"]

                                im_merge = copy.deepcopy(im_split)
                                im_merge[ch] = transformed_channel
                                merged_transformed = cv2.merge(im_merge)
                                name_tag_ch = "_ch-" + str(ch + 1) + ch_name_tag
                                # print(name_ch)
                                # cv2_imshow(merged)
                                # save
                                name = (
                                    title
                                    + "_"
                                    + str(count)
                                    + "_"
                                    + name_tag
                                    + name_tag_ch
                                )
                                # print(name)
                                if dice <= train:
                                    p_name = (
                                        dir_image_train
                                        + "/"
                                        + name
                                        + output_image_format
                                    )
                                else:
                                    p_name = (
                                        dir_image_val + "/" + name + output_image_format
                                    )

                                cv2.imwrite(p_name, merged_transformed)
                                print("Writing " + name)
                                # print(transformed_bboxes)
                                # writeVoc(transformed_bboxes, count, transformed_image)
                                # pTitle='/content/'+dir+'/'+title
                                if dice <= train:
                                    p_title = dir_label_train + "/" + name
                                else:
                                    p_title = dir_label_val + "/" + name

                                self.write_yolo(transformed_bboxes, p_title)
                                count = count + 1
                        # except:
                        # print("Augmentation exception!!!")
                        # pass
        print("Process created {} images".format(count))

# %%
from SciAugment.utilities.SciAug_tools import *

# %%
#@markdown Specifie a path to folder with images and YOLO anotations
input_images_folder = '/content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames+labels_additional/'  # @param{type: 'string'}
input_image_format = '.jpg'  # @param{type: 'string'}

# %%
aug = SciAugment()
# Out:
# New instance of SciAugment.
# Selected augmentation type: Default
#
#
# Version: 0.2.0
#
#
# Selected augmentation:
# no augmentation
# HorizontalFlip(p=1)
# RandomSizedBBoxSafeCrop(250, 250, erosion_rate=0.0, interpolation=1, p=1.0)
# Transpose(1)
# RandomRotate90(p=1)
# ShiftScaleRotate(p=1)
# VerticalFlip(p=1)

# %%
aug.augment_data(images_path=input_images_folder, image_format=input_image_format)
# Out:
# Num of files: 43
# Processing: frame_0015.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames+labels_additional/
# frame_0015.jpg
# Processing: frame_0015.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames+labels_additional/frame_0015.txt
# Writing frame_0015_0_000000000000.jpg
# Writing frame_0015_1_000010000000.jpg
# Writing frame_0015_2_000000010000.jpg
# Writing frame_0015_3_000000000100.jpg
# Writing frame_0015_4_000000000010.jpg
# Writing frame_0015_5_111000000000.jpg
# Writing frame_0015_6_000100000000.jpg
# Processing: frame_0016.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames+labels_additional/
# frame_0016.jpg
# Processing: frame_0016.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames+labels_additional/frame_0016.txt
# Writing frame_0016_7_000000000000.jpg
# Writing frame_0016_8_000010000000.jpg
# Writing frame_0016_9_000000010000.jpg
# Writing frame_0016_10_000000000100.jpg
# Writing frame_0016_11_000000000010.jpg
# Writing frame_0016_12_111000000000.jpg
# Writing frame_0016_13_000100000000.jpg
# Processing: frame_0019.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames+labels_additional/
# frame_0019.jpg
# Processing: frame_0019.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames+labels_additional/frame_0019.txt
# Writing frame_0019_14_000000000000.jpg
# Writing frame_0019_15_000010000000.jpg
# Writing frame_0019_16_000000010000.jpg
# Writing frame_0019_17_000000000100.jpg
# Writing frame_0019_18_000000000010.jpg
# Writing frame_0019_19_111000000000.jpg
# Writing frame_0019_20_000100000000.jpg
# Processing: frame_0020.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames+labels_additional/
# frame_0020.jpg
# Processing: frame_0020.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames+labels_additional/frame_0020.txt
# Writing frame_0020_21_000000000000.jpg
# Writing frame_0020_22_000010000000.jpg
# Writing frame_0020_23_000000010000.jpg
# Writing frame_0020_24_000000000100.jpg
# Writing frame_0020_25_000000000010.jpg
# Writing frame_0020_26_111000000000.jpg
# Writing frame_0020_27_000100000000.jpg
# Processing: frame_0021.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames+labels_additional/
# frame_0021.jpg
# Processing: frame_0021.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames+labels_additional/frame_0021.txt
# Writing frame_0021_28_000000000000.jpg
# Writing frame_0021_29_000010000000.jpg
# Writing frame_0021_30_000000010000.jpg
# Writing frame_0021_31_000000000100.jpg
# Writing frame_0021_32_000000000010.jpg
# Writing frame_0021_33_111000000000.jpg
# Writing frame_0021_34_000100000000.jpg
# Processing: frame_0022.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames+labels_additional/
# frame_0022.jpg
# Processing: frame_0022.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames+labels_additional/frame_
txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames+labels_additional/frame_0052.txt
# Writing frame_0052_91_000000000000.jpg
# Writing frame_0052_92_000010000000.jpg
# Writing frame_0052_93_000000010000.jpg
# Writing frame_0052_94_000000000100.jpg
# Writing frame_0052_95_000000000010.jpg
# Writing frame_0052_96_111000000000.jpg
# Writing frame_0052_97_000100000000.jpg
# Processing: frame_0055.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames+labels_additional/
# frame_0055.jpg
# Processing: frame_0055.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames+labels_additional/frame_0055.txt
# Writing frame_0055_98_000000000000.jpg
# Writing frame_0055_99_000010000000.jpg
# Writing frame_0055_100_000000010000.jpg
# Writing frame_0055_101_000000000100.jpg
# Writing frame_0055_102_000000000010.jpg
# Writing frame_0055_103_111000000000.jpg
# Writing frame_0055_104_000100000000.jpg
# Processing: frame_0061.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames+labels_additional/
# frame_0061.jpg
# Processing: frame_0061.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames+labels_additional/frame_0061.txt
# Writing frame_0061_105_000000000000.jpg
# Writing frame_0061_106_000010000000.jpg
# Writing frame_0061_107_000000010000.jpg
# Writing frame_0061_108_000000000100.jpg
# Writing frame_0061_109_000000000010.jpg
# Writing frame_0061_110_111000000000.jpg
# Writing frame_0061_111_000100000000.jpg
# Processing: frame_0064.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames+labels_additional/
# frame_0064.jpg
# Processing: frame_0064.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames+labels_additional/frame_0064.txt
# Writing frame_0064_112_000000000000.jpg
# Writing frame_0064_113_000010000000.jpg
# Writing frame_0064_114_000000010000.jpg
# Writing frame_0064_115_000000000100.jpg
# Writing frame_0064_116_000000000010.jpg
# Writing frame_0064_117_111000000000.jpg
# Writing frame_0064_118_000100000000.jpg
# Processing: frame_0072.jpg
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames+labels_additional/
# frame_0072.jpg
# Processing: frame_0072.txt
# /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames+labels_additional/frame_0072.txt
# Writing frame_0072_119_000000000000.jpg
# Writing frame_0072_120_000010000000.jpg
# Writing frame_0072_121_000000010000.jpg
# Writing frame_0072_122_000000000100.jpg

# %%
import shutil
shutil.make_archive('gdrive/Shareddrives/YOLObee_drive/02_Code/train_data_part2','zip','/content/', base_dir='train_data')
# Out:
# '/content/gdrive/Shareddrives/YOLObee_drive/02_Code/train_data_part2.zip'

# %%
import shutil
shutil.copytree('/content/train_data','gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/train_data')
# Out:
# 'gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/train_data'

# %% [markdown]
# Training
# ---

# %%
# %cd yolov5
# Out:
# /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/yolov5

# %%
#!git clone https://github.com/ultralytics/yolov5  # clone

# %pip install -qr /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/yolov5/requirements.txt  # install

import torch

from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-314-g60dde7f1 Python-3.10.12 torch-2.3.0+cu121 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.0/107.7 GB disk)

# %%
# %cd data
# !wget https://github.com/martinschatz-cz/SciCount/raw/main/example_notebooks/WildlifeDetection/class1.yaml
# %cd ..

# %%
# Train YOLOv5s on Smear images augmented train_data for 800 epochs
# !python train.py --img 640 --batch -1 --epochs 800 --data class1.yaml --weights /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/yolov5/runs/train/best_training_01/weights/best.pt --cache
# Out:
# 2024-06-04 11:25:39.444555: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-04 11:25:39.444612: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-04 11:25:39.446772: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=/content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/yolov5/runs/train/exp20/weights/best.pt, cfg=, data=class1.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=800, batch_size=-1, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: ⚠️ YOLOv5 is out of date by 4 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-314-g60dde7f1 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
#
#                  from  n    params  module                                  arguments
#   0                -1  1      5280  models.common.Conv                      [3, 48, 6, 2, 2]
#   1                -1  1     41664  models.common.Conv                      [48, 96, 3, 2]
#   2                -1  2     65280  models.common.C3                        [96, 96, 2]
#   3                -1  1    166272  models.common.Conv                      [96, 192, 3, 2]
#   4                -1  4    444672  models.common.C3                        [192, 192, 4]
#   5                -1  1    664320  models.common.Conv                      [192, 384, 3, 2]
#   6                -1  6   2512896  models.common.C3                        [384, 384, 6]
#   7                -1  1   2655744  models.common.Conv                      [384, 768, 3, 2]
#   8                -1  2   4134912  models.common.C3                        [768, 768, 2]
#   9                -1  1   1476864  models.common.SPPF                      [768, 768, 5]
#  10                -1  1    295680  models.common.Conv                      [768, 384, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  2   1182720  models.common.C3                        [768, 384, 2, False]
#  14                -1  1     74112  models.common.Conv                      [384, 192, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  2    296448  models.common.C3                        [384, 192, 2, False]
#  18                -1  1    332160  models.common.Conv                      [192, 192, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  2   1035264  models.common.C3                        [384, 384, 2, False]
#  21                -1  1   1327872  models.common.Conv                      [384, 384, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  2   4134912  models.common.C3                        [768, 768, 2, False]
#  24      [17, 20, 23]  1     24246  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [192, 384, 768]]
# Model summary: 291 layers, 20871318 parameters, 20871318 gradients, 48.2 GFLOPs
#
# Transferred 481/481 items from /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/yolov5/runs/train/exp20/weights/best.pt
# WARNING ⚠️ NMS time limit 0.550s exceeded
# AMP: checks passed ✅
# AutoBatch: Computing optimal batch size for --imgsz 640
# AutoBatch: CUDA:0 (Tesla T4) 14.75G total, 0.35G reserved, 0.16G allocated, 14.24G free
#       Params      GFLOPs  GPU_mem (GB)  forward (ms) backward (ms)                   input                  output
#     20871318       48.22         0.535         28.93         49.09        (1, 3, 640, 640)                    list
#     20871318       96.44         0.830         47.87         44.21        (2, 3, 640, 640)                    list
#     20871318       192.9         1.523          48.9         51.75        (4, 3, 640, 640)                    list
#     20871318       385.8         2.898         82.95         75.37        (8, 3, 640, 640)                    list
#     20871318       771.5         5.738         151.9         140.6       (16, 3, 640, 640)                    list
# AutoBatch: Using batch-size
[00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:05<00:00,  2.96s/it]
#                    all         53        134      0.816      0.724       0.72      0.253
# Speed: 1.3ms pre-process, 13.1ms inference, 31.6ms NMS per image at shape (32, 3, 320, 320)
# Results saved to runs/val/exp7

# %% [markdown]
# Detection
# ---

# %%
# !python detect.py --weights /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/yolov5/runs/train/exp25/weights/best.pt --img 640 --source '/content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames/frame_0047.jpg' --save-txt --save-conf
# Out:
# detect: weights=['/content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/yolov5/runs/train/exp25/weights/best.pt'], source=/content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames/frame_0047.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-314-g60dde7f1 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/gdrive/Shareddrives/YOLObee_drive/01_Data/frames/frame_0047.jpg: 384x640 3 ans, 48.2ms
# Speed: 0.6ms pre-process, 48.2ms inference, 671.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp22
# 1 labels saved to runs/detect/exp22/labels

# %%
# !python detect.py --weights /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/yolov5/runs/train/exp25/weights/best.pt --img 640 --source '/content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov' --save-txt --save-conf
# Out:
# detect: weights=['/content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/yolov5/runs/train/exp25/weights/best.pt'], source=/content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-314-g60dde7f1 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# video 1/1 (1/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 48.6ms
# video 1/1 (2/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (3/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (4/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (5/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (6/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (7/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (8/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (9/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (10/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (11/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (12/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (13/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (14/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (15/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (16/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (17/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (18/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (19/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (20/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (21/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (22/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (23/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (24/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (25/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (26/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (27/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (28/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (29/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (30/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (31/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (32/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 3 ans, 19.8ms
# video 1/1 (33/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 3 ans, 19.8ms
# video 1/1 (34/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (35/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (36/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 3 ans, 19.8ms
# video 1/1 (37/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 3 ans, 19.8ms
# video 1/1 (38/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 3 ans, 21.6ms
# video 1/1 (39/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 3 ans, 19.8ms
# video 1/1 (40/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 3 ans, 19.8ms
# video 1/1 (41/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 3 ans, 19.8ms
# video 1/1 (42/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (43/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (44/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (45/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (46/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (47/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.9ms
# video 1/1 (48/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (49/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (50/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (51/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 21.3ms
# video 1/1 (52/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (53/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (54/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (55/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (56/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (57/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (58/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (59/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 28.3ms
# video 1/1 (60/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 28.0ms
# video 1/1 (61/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (62/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 22.4ms
# video 1/1 (63/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 27.8ms
# video 1/1 (64/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (65/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (66/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 25.9ms
# video 1/1 (67/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (68/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 24.5ms
# video 1/1 (69/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 23.2ms
# video 1/1 (70/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 20.2ms
# video 1/1 (71/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 30.4ms
# video 1/1 (72/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 25.2ms
# video 1/1 (73/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 22.4ms
# video 1/1 (74/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 20.7ms
# video 1/1 (75/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (76/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 24.5ms
# video 1/1 (77/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 21.2ms
# video 1/1 (78/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 21.6ms
# video 1/1 (79/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 28.6ms
# video 1/1 (80/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 25.7ms
# video 1/1 (81/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 25.5ms
# video 1/1 (82/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (83/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 22.1ms
# video 1/1 (84/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.9ms
# video 1/1 (85/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 21.6ms
# video 1/1 (86/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 34.1ms
# video 1/1 (87/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (88/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 22.9ms
# video 1/1 (89/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (90/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 23.1ms
# video 1/1 (91/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 22.4ms
# video 1/1 (92/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 21.0ms
# video 1/1 (93/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 28.7ms
# video 1/1 (94/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (95/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (96/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (97/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 25.4ms
# video 1/1 (98/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (99/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 25.5ms
# video 1/1 (100/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 22.1ms
# video 1/1 (101/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 25.9ms
# video 1/1 (102/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 24.5ms
# video 1/1 (103/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (104/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (105/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (106/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (107/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (108/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 20.1ms
# video 1/1 (109/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (110/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (111/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (112/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (113/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.9ms
# video 1/1 (114/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (115/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 23.6ms
# video 1/1 (116/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (117/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 22.0ms
# video 1/1 (118/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (119/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (120/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (121/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 21.6ms
# video 1/1 (122/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (123/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (124/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (125/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (126/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.9ms
# video 1/1 (127/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (128/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (129/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (130/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (131/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (132/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (133/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (134/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 5 ans, 19.8ms
# video 1/1 (135/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (136/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (137/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (138/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (139/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 20.0ms
# video 1/1 (140/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 5 ans, 19.8ms
# video 1/1 (141/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (142/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (143/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (144/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (145/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (146/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (147/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (148/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (149/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (150/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 20.0ms
# video 1/1 (151/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (152/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (153/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (154/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (155/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (156/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (157/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (158/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (159/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (160/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.9ms
# video 1/1 (161/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (162/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (163/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (164/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (165/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (166/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 21.2ms
# video 1/1 (167/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (168/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (169/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (170/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (171/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (172/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (173/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (174/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (175/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (176/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (177/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (178/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (179/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (180/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (181/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (182/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (183/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (184/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (185/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (186/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (187/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (188/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (189/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 20.2ms
# video 1/1 (190/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (191/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (192/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (193/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (194/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.9ms
# video 1/1 (195/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (196/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 21.7ms
# video 1/1 (197/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (198/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (199/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.9ms
# video 1/1 (200/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (201/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 20.0ms
# video 1/1 (202/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (203/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (204/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (205/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (206/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (207/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (208/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.9ms
# video 1/1 (209/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 21.8ms
# video 1/1 (210/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (211/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (212/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (213/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (214/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (215/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (216/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (217/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (218/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (219/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (220/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 20.9ms
# video 1/1 (221/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (222/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (223/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (224/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (225/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (226/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (227/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (228/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (229/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (230/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (231/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (232/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (233/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (234/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (235/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (236/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (237/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (238/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (239/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 21.1ms
# video 1/1 (240/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (241/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (242/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (243/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (244/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.9ms
# video 1/1 (245/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (246/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 25.7ms
# video 1/1 (247/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (248/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (249/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (250/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 21.9ms
# video 1/1 (251/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.9ms
# video 1/1 (252/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (253/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (254/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (255/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 25.3ms
# video 1/1 (256/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 22.9ms
# video 1/1 (257/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (258/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (259/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 23.8ms
# video 1/1 (260/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 29.2ms
# video 1/1 (261/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (262/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 22.0ms
# video 1/1 (263/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 21.7ms
# video 1/1 (264/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 24.0ms
# video 1/1 (265/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 31.1ms
# video 1/1 (266/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (267/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 24.5ms
# video 1/1 (268/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (269/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (270/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 23.0ms
# video 1/1 (271/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 24.4ms
# video 1/1 (272/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 24.2ms
# video 1/1 (273/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 29.2ms
# video 1/1 (274/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 3 ans, 24.1ms
# video 1/1 (275/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (276/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 24.6ms
# video 1/1 (277/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (278/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 5 ans, 19.8ms
# video 1/1 (279/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 23.5ms
# video 1/1 (280/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 3 ans, 27.6ms
# video 1/1 (281/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 27.3ms
# video 1/1 (282/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 3 ans, 25.7ms
# video 1/1 (283/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 3 ans, 25.4ms
# video 1/1 (284/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 21.1ms
# video 1/1 (285/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 27.7ms
# video 1/1 (286/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 3 ans, 24.3ms
# video 1/1 (287/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 28.1ms
# video 1/1 (288/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 29.6ms
# video 1/1 (289/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 25.2ms
# video 1/1 (290/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 20.4ms
# video 1/1 (291/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 3 ans, 19.8ms
# video 1/1 (292/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 3 ans, 25.8ms
# video 1/1 (293/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 3 ans, 24.3ms
# video 1/1 (294/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 3 ans, 19.8ms
# video 1/1 (295/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 3 ans, 19.8ms
# video 1/1 (296/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (297/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (298/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (299/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (300/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (301/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (302/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (303/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (304/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.9ms
# video 1/1 (305/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (306/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 4 ans, 19.8ms
# video 1/1 (307/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 3 ans, 19.8ms
# video 1/1 (308/308) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract_2.mov: 384x640 3 ans, 19.8ms
# Speed: 0.6ms pre-process, 21.0ms inference, 3.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp23
# 308 labels saved to runs/detect/exp23/labels

# %%
# !python detect.py --weights /content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/yolov5/runs/train/exp25/weights/best.pt --img 640 --source '/content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov' --save-txt --save-conf
# Out:
# detect: weights=['/content/gdrive/Shareddrives/YOLObee_drive/02_Code/YOLOv5/yolov5/runs/train/exp25/weights/best.pt'], source=/content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-314-g60dde7f1 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# video 1/1 (1/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 48.2ms
# video 1/1 (2/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (3/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (4/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 1 an, 19.8ms
# video 1/1 (5/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (6/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (7/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (8/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (9/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (10/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 1 an, 19.8ms
# video 1/1 (11/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 1 an, 19.8ms
# video 1/1 (12/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 1 an, 19.8ms
# video 1/1 (13/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 23.1ms
# video 1/1 (14/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (15/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 3 ans, 19.8ms
# video 1/1 (16/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 3 ans, 19.9ms
# video 1/1 (17/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 3 ans, 19.8ms
# video 1/1 (18/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 3 ans, 19.8ms
# video 1/1 (19/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (20/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 3 ans, 19.8ms
# video 1/1 (21/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 3 ans, 19.8ms
# video 1/1 (22/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 3 ans, 19.8ms
# video 1/1 (23/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (24/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 1 an, 19.8ms
# video 1/1 (25/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (26/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 1 an, 19.8ms
# video 1/1 (27/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (28/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (29/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 3 ans, 19.8ms
# video 1/1 (30/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 3 ans, 19.8ms
# video 1/1 (31/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.9ms
# video 1/1 (32/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 1 an, 19.8ms
# video 1/1 (33/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 1 an, 19.8ms
# video 1/1 (34/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (35/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 1 an, 19.8ms
# video 1/1 (36/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (37/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (38/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (39/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (40/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (41/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (42/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 3 ans, 19.8ms
# video 1/1 (43/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (44/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 1 an, 19.8ms
# video 1/1 (45/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.9ms
# video 1/1 (46/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 1 an, 19.8ms
# video 1/1 (47/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 1 an, 19.9ms
# video 1/1 (48/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.9ms
# video 1/1 (49/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (50/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 1 an, 19.9ms
# video 1/1 (51/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (52/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (53/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (54/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (55/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.9ms
# video 1/1 (56/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (57/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (58/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (59/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (60/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (61/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (62/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (63/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 1 an, 19.9ms
# video 1/1 (64/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 1 an, 19.8ms
# video 1/1 (65/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 1 an, 19.8ms
# video 1/1 (66/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 1 an, 19.8ms
# video 1/1 (67/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 (no detections), 19.8ms
# video 1/1 (68/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 1 an, 19.9ms
# video 1/1 (69/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (70/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 1 an, 19.8ms
# video 1/1 (71/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (72/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.9ms
# video 1/1 (73/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (74/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (75/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (76/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 3 ans, 19.8ms
# video 1/1 (77/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (78/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (79/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 (80/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.9ms
# video 1/1 (81/129) /content/gdrive/Shareddrives/YOLObee_drive/01_Data/bees_extract.mov: 384x640 2 ans, 19.8ms
# video 1/1 